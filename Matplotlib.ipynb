# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.6.2

# %% [markdown]
# Pyplot

# %% [markdown]
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt


xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
x1 = np.array([1, 8])
y1 = np.array([3, 10])
plt.plot(x1, y1)
plt.show()

# %%
x2 = np.array([10, 25])
y2 = np.array([1, 11])
plt.plot(x2, y2, 'o')
plt.show()

# %%
x3 = np.array([1, 3, 8, 13])
y3 = np.array([3, 8, 1, 0])
plt.plot(x3, y3)
plt.show()

# %%
x3 = np.array([1, 3, 8, 13])
y3 = np.array([3, 8, 1, 0])
plt.plot(x3, y3, 'o')
plt.show()

# %% [markdown]
# Default X-Points----
#
#
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 (etc., depending on the length of the y-points.

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, 'o')
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, marker = 'o')
plt.show()

# %%
# mark each point with a star(*)
y4 = np.array([1, 8, 3,10, 11, 7])
plt.plot(y4, marker = '1')
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, 'o:g')
plt.show()

# %% [markdown]
# market size

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, 'o:r', ms = 15)
plt.show()

# %% [markdown]
# Marker Color--
#
#
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, 'o:r', ms = 15, mec = 'r')
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, marker = 'o', ms = 15, mec = 'r', mfc = 'g')
plt.show()

# %%
# you can use hexadecimal color values
y4 = np.array([1, 8, 3, 10, 11, 7])
plt.plot(y4, marker = 'o', ms = 15, mec = '#4CAF50', mfc = 'g')
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'dotted') 
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, 'o', mec = 'g', mfc = 'r',  ls = 'dashed') 
# ls is the short name for linestyle
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'solid') 
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'dashdot') 
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'solid') 
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'solid', color = 'y') 
plt.show()

# %%
y4 = np.array([1, 8, 3, 10, 11, 7])
# use dotted to change the style of the line
plt.plot(y4, ls = 'dashdot', linewidth = 6) 
plt.show()

# %%
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
plt.plot(y5)
plt.plot(y6)
plt.show()

# %%
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
y7 = np.array([56, 23, 43, 1, 3, 6])
y8 = np.array([10, 12, 5, 11, 14, 9])
plt.plot(y5, y6, y7, y8, ls = 'dotted', mfc = 'g')
plt.show()

# %% [markdown]
# Add labels on the x and y axis

# %%
# add labels in the x and y axis

y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
plt.plot(y5)
plt.plot(y6)
plt.xlabel('Average Pulse')
plt.ylabel('Calorie Burnage')
plt.show()

# %%
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
y7 = np.array([56, 23, 43, 1, 3, 6])
y8 = np.array([10, 12, 5, 11, 14, 9])
plt.plot(y5, y6, y7, y8, ls = 'dotted', mfc = 'g')
plt.xlabel('heartbeat')
plt.ylabel('calorie burnage')
plt.show()

# %% [markdown]
# add the title

# %%
# let's add a title
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
y7 = np.array([56, 23, 43, 1, 3, 6])
y8 = np.array([10, 12, 5, 11, 14, 9])
plt.plot(y5, y6, y7, y8, ls = 'dotted', mfc = 'g')
plt.title('Sports Watch Data')
plt.xlabel('heartbeat')
plt.ylabel('calorie burnage')
plt.show()

# %% [markdown]
# Set Font Properties for Title and Labels--
#
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
# let's add some properties for the title and labels
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
y7 = np.array([56, 23, 43, 1, 3, 6])
y8 = np.array([10, 12, 5, 11, 14, 9])


font1 = {'family':'serlf' , 'color':'blue' , 'size':20}
font2 = {'family':'serif' , 'color':'darkred' , 'size':15}
plt.title('Sports Watch Data', fontdict = font1)
plt.xlabel('heartbeat', fontdict = font2)
plt.ylabel('calorie burnage', fontdict = font2)
plt.plot(y5, y6, y7, y8, ls = 'dotted', mfc = 'g')
plt.show()
# Out:
# findfont: Font family 'serlf' not found.
# findfont: Font family 'serlf' not found.
# findfont: Font family 'serlf' not found.
# findfont: Font family 'serlf' not found.
# findfont: Font family 'serlf' not found.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2, loc = 'right')
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# Specify Which Grid Lines to Display--
#
#
# You can use the axis parameter in the grid() function to specify which grid lines to display.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis = 'x')
plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(color = 'r', linewidth = 0.5, ls = 'dashdot')
plt.show()

# %% [markdown]
# Display Multiple Plots---
# With the subplot() function you can draw multiple plots in one figure:

# %%
x1 = np.array([1, 8])
y1 = np.array([3, 10])
plt.subplot(2, 1, 1)
plt.plot(x1, y1)

x2 = np.array([4, 7])
y2 = np.array([4, 9])
plt.subplot(2, 1, 2)
plt.plot(x2, y2)
plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title('Chart 1')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title('chart 2')

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.plot('chart 3')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title('chart 4')

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title('chart 5')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title('chart 6')
plt.suptitle('Awesome charting')

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
y5 = np.array([2, 5, 1, 90, 56, 43])
y6 = np.array([10, 23, 33, 13, 7, 29])
plt.plot(y5)
plt.plot(y6)
plt.xlabel('Average Pulse')
plt.ylabel('Calorie Burnage')
plt.show()

# %%
x3 = np.array([1, 3, 8, 13])
y3 = np.array([3, 8, 1, 0])
plt.scatter(x3, y3)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'g')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'r')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors, cmap = 'viridis')
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_2878/1656970000.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=colors, cmap = 'viridis')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
sizes = np.array([11, 200, 300, 43, 50, 600, 700, 80, 900, 100, 111, 120, 130])
plt.scatter(x, y, c=colors, s = sizes)

plt.show()

# %% [markdown]
# You can adjust the transparency of the dots with the alpha argument.

# %%
# you can set the transparency
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
sizes = np.array([11, 200, 300, 43, 50, 600, 700, 80, 900, 100, 111, 120, 130])
plt.scatter(x, y, c=colors, s = sizes, alpha = 1, cmap='nipy_spectral')

plt.show()
# Out:
# /tmp/ipykernel_2878/170094640.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=colors, s = sizes, alpha = 1, cmap='nipy_spectral')

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
# create bar char
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
# horizontal bar
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y)
plt.show()

# %%
# let's change the bar color
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, color = 'r')
plt.show()

# %%
# let's change the width of the bar
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y, width = 0.2)
plt.show()

# %%
x = np.random.normal(170, 10, 110)
print(x)
# Out:
# [169.03967992 168.25429495 164.31714419 170.40250065 188.65307873
#  153.35158543 164.77074114 166.80689058 186.78109508 172.17338352
#  178.13720122 163.69628104 169.07856827 151.36077476 168.77414838
#  161.64097062 171.34693931 170.50604167 161.27653347 171.47512546
#  163.876254   167.60978686 179.79104882 174.16128212 167.82043822
#  166.32983272 174.27878617 154.52786739 175.28842411 171.23241974
#  178.49847033 156.59407628 154.55859898 172.8156851  175.83482836
#  155.33395356 164.62290982 173.14487059 159.01726114 181.23593873
#  164.87025459 181.99837942 174.24021476 149.45541004 174.95811588
#  183.16971628 187.06885892 171.83800563 169.57848531 176.16136733
#  170.0942645  173.7021395  148.94288998 169.56906265 181.19598162
#  184.26836448 152.07777563 184.46339257 164.29346667 179.34490845
#  174.6394614  175.69790902 163.86192287 173.69888962 173.03948646
#  158.58491598 175.42718191 174.14501073 147.02735278 159.4692342
# ...

# %%
plt.hist(x)
plt.show()

# %%
# let's create pie chart

y = np.array([3, 8, 1, 10])
my_labels = ['Google', 'Meta', 'Netflix', 'Microsoft']
plt.pie(y, labels = my_labels)
plt.show()

# %%
# let's change the start angle
y = np.array([3, 8, 1, 10])
my_labels = ['Google', 'Meta', 'Netflix', 'Microsoft']
plt.pie(y, labels = my_labels, startangle = 70)
plt.show()

# %%
y = np.array([3, 8, 1, 10])
my_labels = ['Google', 'Meta', 'Netflix', 'Microsoft']
myexplode = [0.1, 0, 0, 0]
plt.pie(y, labels = my_labels, explode = myexplode)
plt.show()

# %%
y = np.array([3, 8, 1, 10])
my_labels = ['Google', 'Meta', 'Netflix', 'Microsoft']
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = my_labels, explode = myexplode, shadow = True)
plt.show()

# %%
y = np.array([3, 8, 1, 10])
my_labels = ['Google', 'Meta', 'Netflix', 'Microsoft']
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = my_labels, explode = myexplode, shadow = True)
plt.legend(title = 'Top Four Companies')
plt.show()
